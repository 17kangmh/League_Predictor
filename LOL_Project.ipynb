# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('high_diamond_ranked_10min.csv')
data
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 0     4519157822         0               28                   2
# 1     4523371949         0               12                   1
# 2     4521474530         0               15                   0
# 3     4524384067         0               43                   1
# 4     4436033771         0               75                   4
# ...          ...       ...              ...                 ...
# 9874  4527873286         1               17                   2
# 9875  4527797466         1               54                   0
# 9876  4527713716         0               23                   1
# 9877  4527628313         0               14                   4
# 9878  4523772935         1               18                   0
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 0                  1          9           6           11                  0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9879 entries, 0 to 9878
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   gameId                        9879 non-null   int64
#  1   blueWins                      9879 non-null   int64
#  2   blueWardsPlaced               9879 non-null   int64
#  3   blueWardsDestroyed            9879 non-null   int64
#  4   blueFirstBlood                9879 non-null   int64
#  5   blueKills                     9879 non-null   int64
#  6   blueDeaths                    9879 non-null   int64
#  7   blueAssists                   9879 non-null   int64
#  8   blueEliteMonsters             9879 non-null   int64
#  9   blueDragons                   9879 non-null   int64
#  10  blueHeralds                   9879 non-null   int64
#  11  blueTowersDestroyed           9879 non-null   int64
#  12  blueTotalGold                 9879 non-null   int64
# ...

# %%
data.dropna()
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 0     4519157822         0               28                   2
# 1     4523371949         0               12                   1
# 2     4521474530         0               15                   0
# 3     4524384067         0               43                   1
# 4     4436033771         0               75                   4
# ...          ...       ...              ...                 ...
# 9874  4527873286         1               17                   2
# 9875  4527797466         1               54                   0
# 9876  4527713716         0               23                   1
# 9877  4527628313         0               14                   4
# 9878  4523772935         1               18                   0
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 0                  1          9           6           11                  0
# ...

# %%
data = data.drop(['redTotalGold', 'redTotalExperience', 'redTotalMinionsKilled', 'redTotalJungleMinionsKilled'], axis = 1)
data = data.drop(['blueTotalGold', 'blueTotalExperience', 'blueTotalMinionsKilled', 'blueTotalJungleMinionsKilled'], axis = 1)
data = data.drop(['gameId'], axis = 1)
data
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0            0               28                   2               1
# 1            0               12                   1               0
# 2            0               15                   0               0
# 3            0               43                   1               0
# 4            0               75                   4               0
# ...        ...              ...                 ...             ...
# 9874         1               17                   2               1
# 9875         1               54                   0               0
# 9876         0               23                   1               0
# 9877         0               14                   4               1
# 9878         1               18                   0               1
#
#       blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# 0             9           6           11                  0            0
# ...

# %%
data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'blueWins'}>,
#         <Axes: title={'center': 'blueWardsPlaced'}>,
#         <Axes: title={'center': 'blueWardsDestroyed'}>,
#         <Axes: title={'center': 'blueFirstBlood'}>,
#         <Axes: title={'center': 'blueKills'}>,
#         <Axes: title={'center': 'blueDeaths'}>],
#        [<Axes: title={'center': 'blueAssists'}>,
#         <Axes: title={'center': 'blueEliteMonsters'}>,
#         <Axes: title={'center': 'blueDragons'}>,
#         <Axes: title={'center': 'blueHeralds'}>,
#         <Axes: title={'center': 'blueTowersDestroyed'}>,
#         <Axes: title={'center': 'blueAvgLevel'}>],
#        [<Axes: title={'center': 'blueGoldDiff'}>,
#         <Axes: title={'center': 'blueExperienceDiff'}>,
#         <Axes: title={'center': 'blueCSPerMin'}>,
#         <Axes: title={'center': 'blueGoldPerMin'}>,
#         <Axes: title={'center': 'redWardsPlaced'}>,
#         <Axes: title={'center': 'redWardsDestroyed'}>],
# ...

# %%
plt.figure(figsize=(25, 10))
heatmap = sns.heatmap(data.corr(), annot=True)
heatmap
# Out:
# <Axes: >

# %%
data = data.drop(['blueAvgLevel', 'redAvgLevel'], axis = 1)

# %%
data = data.drop(['redFirstBlood', 'redKills', 'redDeaths'], axis = 1)

# %%
data = data.drop(['redGoldDiff', 'redExperienceDiff', 'blueExperienceDiff', 'blueGoldDiff'], axis = 1)

# %%
data = data.drop(['redGoldPerMin', 'redCSPerMin', 'blueGoldPerMin', 'blueCSPerMin'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
X = data.drop(['blueWins'], axis = 1)
y = data['blueWins']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

logReg = LogisticRegression(max_iter=1000)
logReg.fit(X_train, y_train)
logPrediction = logReg.predict(X_test)
logRegScore = accuracy_score(y_test, logPrediction)
logRegScore
# Out:
# 0.7145748987854251

# %%
coefficients = logReg.coef_[0]
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': np.abs(coefficients)})
feature_importance = feature_importance.sort_values('Importance', ascending=True)
feature_importance.plot(x='Feature', y='Importance', kind='barh', figsize=(10, 6))
# Out:
# <Axes: ylabel='Feature'>

# %%
data
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0            0               28                   2               1
# 1            0               12                   1               0
# 2            0               15                   0               0
# 3            0               43                   1               0
# 4            0               75                   4               0
# ...        ...              ...                 ...             ...
# 9874         1               17                   2               1
# 9875         1               54                   0               0
# 9876         0               23                   1               0
# 9877         0               14                   4               1
# 9878         1               18                   0               1
#
#       blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# 0             9           6           11                  0            0
# ...

# %%
dataClone = data[['blueWins', 'blueKills', 'blueDeaths', 'blueTowersDestroyed', 'blueDragons']]

# %%
dataClone
# Out:
#       blueWins  blueKills  blueDeaths  blueTowersDestroyed  blueDragons
# 0            0          9           6                    0            0
# 1            0          5           5                    0            0
# 2            0          7          11                    0            1
# 3            0          4           5                    0            0
# 4            0          6           6                    0            0
# ...        ...        ...         ...                  ...          ...
# 9874         1          7           4                    0            1
# 9875         1          6           4                    0            1
# 9876         0          6           7                    0            0
# 9877         0          2           3                    0            1
# 9878         1          6           6                    0            0
#
# [9879 rows x 5 columns]

# %%
dataClone = dataClone.rename(columns={'blueDeaths': 'redKills'})

# %%
dataClone
# Out:
#       blueWins  blueKills  redKills  blueTowersDestroyed  blueDragons
# 0            0          9         6                    0            0
# 1            0          5         5                    0            0
# 2            0          7        11                    0            1
# 3            0          4         5                    0            0
# 4            0          6         6                    0            0
# ...        ...        ...       ...                  ...          ...
# 9874         1          7         4                    0            1
# 9875         1          6         4                    0            1
# 9876         0          6         7                    0            0
# 9877         0          2         3                    0            1
# 9878         1          6         6                    0            0
#
# [9879 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X = dataClone.drop(['blueWins'], axis = 1)
y = dataClone['blueWins']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_Scaler_train = scaler.fit_transform(X_train)
X_Scaler_test = scaler.transform(X_test)

logReg = LogisticRegression(max_iter=1000)
logReg.fit(X_Scaler_train, y_train)
logPrediction = logReg.predict(X_Scaler_test)

# %%
from sklearn.metrics import mean_squared_error

error = np.sqrt(mean_squared_error(y_test, logPrediction))
error
# Out:
# 0.5450364917397139

# %%
from sklearn.tree import DecisionTreeRegressor

decTreeReg = DecisionTreeRegressor(random_state=0)
decTreeReg.fit(X_Scaler_train, y_train)
decTreeRegPred = decTreeReg.predict(X_Scaler_test)

# %%
error = np.sqrt(mean_squared_error(y_test, decTreeRegPred))
error
# Out:
# 0.6226169142115786

# %%
from sklearn.ensemble import RandomForestRegressor

randForReg = RandomForestRegressor(random_state=0)
randForReg.fit(X_Scaler_train, y_train)
randForRegPred = randForReg.predict(X_Scaler_test)

error = np.sqrt(mean_squared_error(y_test, randForRegPred))
error
# Out:
# 0.44689486798943423

# %%
from sklearn.model_selection import GridSearchCV

max_depth = [None, 2, 4, 6, 8, 10]
parameters = {'max_depth': max_depth}

regressor = DecisionTreeRegressor(random_state=0)
gs = GridSearchCV(regressor, parameters, scoring = 'neg_mean_squared_error')
gs.fit(X_train,y_train)

newRegressor = gs.best_estimator_

newRegressor.fit(X_Scaler_train, y_train)
newRegPred = newRegressor.predict(X_Scaler_test)

error = np.sqrt(mean_squared_error(y_test, newRegPred))
error
# Out:
# 0.4389789809375425

# %%
from sklearn.model_selection import GridSearchCV

max_depth = [None, 2, 4, 6, 8, 10]
parameters = {'max_depth': max_depth}

regressor = RandomForestRegressor(random_state=0)
gsFor = GridSearchCV(regressor, parameters, scoring = 'neg_mean_squared_error')
gsFor.fit(X_train,y_train)

newForRegressor = gsFor.best_estimator_

newForRegressor.fit(X_Scaler_train, y_train)
newForRegPred = newForRegressor.predict(X_Scaler_test)

error = np.sqrt(mean_squared_error(y_test, newForRegPred))
error
# Out:
# 0.4355095336770548

# %%
X_train
# Out:
#       blueKills  redKills  blueTowersDestroyed  blueDragons
# 9136          7         5                    0            0
# 2741          8         6                    0            1
# 8112         10         3                    0            0
# 8777          7         8                    0            0
# 417           4         7                    0            1
# ...         ...       ...                  ...          ...
# 1941          5         3                    0            0
# 4916         12        10                    0            1
# 4828          9         9                    0            1
# 8173          6         5                    0            0
# 5771          3         7                    0            0
#
# [7903 rows x 4 columns]

# %%
newData = np.array([[30, 2, 4, 3]])

# %%
newDataPred = newForRegressor.predict(newData)
newDataPred
# Out:
# array([0.88850515])

# %%
import pickle

# %%
Leag_Pred_Model = {'model': newForRegressor}
pickle.dump(newForRegressor, open('lol_pred_model.pkl', 'wb'))

# %%
loaded_model = pickle.load(open('lol_pred_model.pkl', 'rb'))

# %%
reg_pred = loaded_model.predict(newData)
reg_pred
# Out:
# array([0.88850515])
